# %%
# !curl -fsSL https://ollama.com/install.sh | sh
# Out:
# >>> Downloading ollama...
# ############################################################################################# 100.0%
# >>> Installing ollama to /usr/local/bin...
# >>> Creating ollama user...
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: Unable to detect NVIDIA/AMD GPU. Install lspci or lshw to automatically detect and install GPU dependencies.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.

# %%
# !rm "/content/myscript.sh"
# !echo '#!/bin/bash' > myscript.sh
# !echo 'ollama serve' >> myscript.sh
# Make the script executable
# !chmod +x myscript.sh
# !nohup ./myscript.sh &
# Out:
# rm: cannot remove '/content/myscript.sh': No such file or directory
# nohup: appending output to 'nohup.out'

# %%
# !nohup ollama run phi3:medium > ollama_model.log 2>&1 &

# %%
#!nohup ollama pull mxbai-embed-large > ollama_emd_model.log 2>&1 &
# !ollama rm phi3:mini

# %%
# !ollama pull llama3
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling ma
# ...

# %%
# !ollama list
# Out:
# Error: could not connect to ollama app, is it running?

# %%
pip install -U langchain-community

# %%
pip install embedchain
# Out:
# ...
#   Using cached langchain-0.1.20-py3-none-any.whl (1.0 MB)
# ...
#   Using cached langchain_community-0.0.38-py3-none-any.whl (2.0 MB)
# ...
#   Using cached langchain_core-0.1.52-py3-none-any.whl (302 kB)
# ...
#   Using cached langchain_text_splitters-0.0.2-py3-none-any.whl (23 kB)
# ...
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.2.1
#     Uninstalling langchain-core-0.2.1:
#       Successfully uninstalled langchain-core-0.2.1
#   Attempting uninstall: langchain-text-splitters
#     Found existing installation: langchain-text-splitters 0.2.0
#     Uninstalling langchain-text-splitters-0.2.0:
#       Successfully uninstalled langchain-text-splitters-0.2.0
#   Attempting uninstall: langchain-community
#     Found existing installation: langchain-community 0.2.1
#     Uninstalling langchain-community-0.2.1:
#       Successfully uninstalled langchain-community-0.2.1
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.2.1
# ...

# %%
# !pip install --upgrade embedchain

# %%
import embedchain
print(embedchain.__version__)
# Out:
# 0.1.104

# %%
pip install sentence-transformers
# Out:
# ...
#   Using cached sentence_transformers-2.7.0-py3-none-any.whl (171 kB)
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...

# %%
from embedchain import App
app = App.from_config(config={
    "llm": {
        "provider": "ollama",
        "config": {
            "model": "llama3",
            "temperature": 0.5,
            "top_p": 1,
            "stream": True
        }
    },
    "embedder": {
        "provider": "huggingface",
        "config": {
            "model": "BAAI/bge-small-en-v1.5"
        }
    }
})
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
app.add("June 03, 2023 Presented at the 59th Annual Meeting of American Society of Clinical Oncology (ASCO 2023), June 02 - 06, 2023, Chicago, Illinois, USA Intratumoral INT230-6 (Cisplatin, Vinblastine, Shao) Alone or with Ipilimumab Prolonged Survival with Favorable Safety in Adults with Refractory Sarcomas Session: Poster Session - Sarcoma Abstract No.: 11568 Christian Frederick Meyer et al. Based on the results presented, GlobalData inferred that RECIST metrics are confounded by intratumoral (IT) injections due to the large volume of highly retained INT230-6 and the influx of immune infiltrates.Analysis of median overall survival (mOS) for INT230-6 alone (n=15) was 649 days. For INT230-6 dosed at a volume/total tumor burden (TTB) ratio of =40%, the median overall survival (mOS) was 715 days. The median overall survival (mOS) of the combination has not been reached with over one year of median follow-up.The overall survival (OS) data compare favorably to a synthetic control (mOS of 205 days) based on historical data. The hazard ratios of INT230-6 alone or with ipilimumab (IPI) for overall survival (OS) to the synthetic control were 0.446 and 0.270, (p-values <0.01). INT230-6, a locally delivered cytotoxic treatment leading to a systemic immune response in hot or cold tumors, is a new way to treat cancer.Compared to synthetic controls INT230-6 alone extended survival in refractory soft tissue sarcoma subjects by nearly 450 days, OS was improved with IPI.Dosing relative to presenting total tumor burden (TTB) show increased survival with higher drug volume loaded for sarcoma subjects administered INT230-6 with or without ipilimumab compared to a synthetic control. Abscopal responses for INT230-6 alone (previously reported) were primarily in subjects dosed = 40% of total tumor burden (TTB).The disease control rate (DCR; Stable disease + partial response + complete response divided by number of subjects) for the all-treated population (those who received at least one dose of INT230-6) was 93% for monotherapy and 86% for the ipilimumab (IPI) combo. https://meetings.asco.org/abstracts-presentations/220646 June 03, 2023 Intensity Therapeutics&#39; INT230-6 Prolongs Survival Alone or in Combination with Ipilimumab in Adult Patients with Relapsed, Refractory, Metastatic Sarcomas Based on the results announced by Intensity Therapeutics, Inc., in the press release, GlobalData inferred that the INT230-6 has demonstrated significant survival prolongation and continues to be of great interest to a sarcoma. Median overall survival (mOS) ranging from 7.6 to 9.6 months.Phase 1/2 studiesControl (Subbiah)INT230-6 allINT230-6 >40% TTBINT230-6 + IPIMedian OS205 days649 daysNot yet reachedNot yet reachedConfidence Interval-(146, NR)--Sample size56151114 https://www.prnewswire.com/news-releases/intensity-therapeutics-int230-6-prolongs-survival-alone-or-in-combination-with-ipilimumab-in-adult-patients-with-relapsed-refractory-metastatic-sarcomas-301841753.html November 18, 2022 Intensity Therapeutics Reports Use of Int230-6 Alone or in Combination with Ipilimumab Shows Evidence of Direct Tumor Necrosis and Promising Overall Survival Results in Adult Subjects with Metastatic Sarcomas at the Connective Tissue Oncology Society (CTOS) 2022 Based on the results announced by Intensity Therapeutics, Inc., in the press release, GlobalData inferred that dosing INT230-6 Equivalent to 40% or More of the Patient’s Tumor Burden During the Course of Therapy Results in a Median Overall Survival of 715 Days Compared to a mOS of 205 days or a Historical Refractory Sarcoma Control.The overall survival of the control, all INT230-6 patients and those receiving a cumulative dose of greater than 40% of their total tumor burden (TTB), were shown in the below table. Subjects receiving combination with ipilimumab have not yet reached median survival with 345 days median follow-up.  Sarcoma subtypes may differ between groups and data is still early.Sarcoma phase 1/2 studiesControl (Subbiah)INT230-6 allINT230-6 >40%TTBINT230-6 + IPIMedian OS205 days649 days715 daysNot yet reachedConfidence Interval-(195, 1352)(649, 1352)Sample size56151114Pharmacokinetic data shows that >95% of the active agents remain in the tumor. Immunohistochemistry showed that there was an increase in the immune cell infiltration pre and post dose. https://intensitytherapeutics.com/intensity-therapeutics-reports-use-of-int230-6-alone-or-in-combination-with-ipilimumab-shows-evidence-of-direct-tumor-necrosis-and-promising-overall-survival-results-in-adult-subjects-with-metastati-2/ November 18, 2022 Matthew A. Ingham,Intratumoral INT230-6 (Cisplatin, Vinblastine, Shao) Alone or with Ipilimumab Prolonged Survival with Favorable Safety in Adults with Refractory Sarcomas, The Annual Meeting of the Connective Tissue Oncology Society (CTOS 2022), Abstract No.: 55, 18 Nov 2022 Based on the results presented, GlobalData inferred that >95% of the active agents remain in the tumor relative to IV dosing at 1 to 6 hours.Retention was independent of cancer type, location, or tumor size.Cisplatin levels are not measured - only (non-toxic) platinum metal is seen in the blood. In metastatic disease injected tumors shrink over time a scan of a chordoma treated with monotherapy highlights tumor regression. Longest diameter declines 15%, whereas 2nd longest diameter declines 42% Using WHO Criteria: Partial Response Using RECIST Criteria: Stable Disease Shrinkage of uninjected tumors observed.The lack of correlation between diameter and volume indicates that RECIST may be unreliable for IT INT230-6 as a metric of efficacy.  Two doses increase CD3, CD4 and CD8 T-cells within the tumor (DAPI). Overall survival increased compared to historical results INT230-6 alone or with ipilimumab in sarcoma. Dose relative to incoming total tumor burden (TTB) show increased survival with higher drug ratio favorable hazard ratios (HR) and abscopal responses reported.https://www.eventscribe.net/2022/CTOS/searchGlobal.asp?mode=Presentations&SearchQuery=INT230-6 November 11, 2022 Intensity Therapeutics&rsquo; INT230-6 Demonstrates Increased Survival As Either Monotherapy or in Combination With Pembrolizumab in Patients With Relapsed, Refractory, Metastatic Solid Tumor Cancers Based on the results announced by Ardelyx, Intensity Therapeutics, Inc., in the press release, GlobalData inferred that by using RECIST criteria, the disease control rate (DCR) rate >50 days for monotherapy was 50.9%; INT230-6 in combination with pembrolizumab showed a disease control rate (DCR) of 47.6%.The INT230-6 all subejcts and those receiving a cumulative dose =40% of total tumor burden (TTB) compare favorable to historical phase 1/2 data where the median overall survival (OS) typically is 3 to 6 months for subjects with one or more risk factors in mixed cancer populations.Phase 1/2 studyHistorical (Chau)INT230-6 allINT230-6 <40% TTBINT230-6 >40% TTBMedian OS90 to 180 days373 days96 days570 daysConfidence Interval–(221, 649)(75, 373)(361, 1621)Sample size641747 https://intensitytherapeutics.com/intensity-therapeutics-int230-6-demonstrates-increased-survival-as-either-monotherapy-or-in-combination-with-pembrolizumab-in-patients-with-relapsed-refractory-metastatic-solid-tumor-cancer-2/ November 08, 2022 Presented at the hybrid 37th Annual Meeting Pre-Conference Programs of the Society for Immunotherapy of Cancer&rsquo;s (SITC 2022), November 8 - 12, 2022, Boston, Massachusetts, United states Safety and Survival Results From a Phase 1/2 Trial of Intratumoral Agent INT230-6 (Cisplatin Vinblastine) Induces Immunological Cancer Cell Death Alone or With Pembrolizumab in Patients With Refractory, Metastatic Cancers Session: Clinical Trials In Progress Abstract No.: 710 Jacob Thomas et al. Based on the results presented, GlobalData inferred that IHC results show marked reduction in DAPI of proliferating cancer cells with influx of CD4 and CD8 T-cells. Non-injected visceral tumors shrank in several INT230-6 monotherapy subjects. Due to drug absorption or immune influx RECIST is not ideal for use with INT230-6.Overall survival is preferred. The estimated median overall survival (mOS) was 361 days for INT230-6, the mOS for the combination has not been reached (173 days of median follow-up).RECIST metrics (sum of longest diameters) such as progression free survival (PFS) or disease control rate (DCR) to gauge a drug’s efficacy are validated for use for systemically delivered therapies.The DCR rate >50 days for monotherapy was 50.9%; however, the INT230-6+PEM DCR was 47.6%. RECIST response principles are not ideal for use with this intratumoral administered therapy.In this study, evaluation of tumors response is complicated by the large amount of INT230-6 repeatedly injected and retained in the tumors prior to the first efficacy scan. In addition, immune infiltration could increase tumor size.Results in a neoadjuvant setting that a single injection causes almost complete necrosis of the entire tumor also indicates that longest diameter is inaccurate in capturing efficacy with this IT technology.In study IT-01 75% of subjects had 1 or more risk factors (predicting a mOS of 90-160 daysv). Early subjects treated generally received a low drug dose relative to their total tumor burden. https://jitc.bmj.com/content/10/Suppl_2/A742 June 05, 2022 Presented at the 58th Annual Meeting of American Society of Clinical Oncology (ASCO 2022), June 03 - 07, 2022, Chicago, Illinois, USA Int230-6 Monotherapy and in Combination with Ipilimumab (Ipi) Across a Broad Spectrum of Refractory Soft Tissue Sarcomas (Sts) [Intensity It-01; Bms#ca184-592] Session: DSarcoma Abstract No.: 11515 Matthew Ingham et al. Based on the results presented, GlobalData inferred that a total of 67 subjects were enrolled in the study.RECIST metrics may not accurately reflect clinical benefit with this treatment given large volumes of INT230-6 is repeatedly injected into a tumor and local inflammation may occur. Paired biopsies showed reduction in proliferating tumor cells and an increase in T-cell infiltrates.The disease control rate at the first imaging timepoint for evaluable INT230-6 subjects (n = 9) was 56% and for evaluable IPI combination (n = 5) was 80%. Abscopal effects were seen in 2 monotherapy subjects, though most uninjected tumors were not tracked.The estimated one year overall survival was observed as 88% for the IPI combo and 60% for the monotherapy cohort. https://meetings.asco.org/abstracts-presentations/208006/slides;https://meetings.asco.org/abstracts-presentations/208006 June 05, 2022 Presented at the 58th Annual Meeting of American Society of Clinical Oncology (ASCO 2022), June 03 - 07, 2022, Chicago, Illinois, USA Effect of Intratumoral INT230-6 on Tumor Necrosis and Promotion of a Systemic Immune Response: Results from a Multicenter Phase 1/2 Study of Solid Tumors with and Without Pembrolizumab (Pem) [Intensity IT-01; Merck Keynote-A10] Session: Developmental Therapeutics&mdash;Immunotherapy Abstract No.: 2520 Jacob Stephen Thomas et al. Based on the results presented, GlobalData inferred that a total of sixty-two subjects received INT230-6 alone and 21 INT230-6 + PEM subjects were analyzed in the study.IHC results confirm a marked reduction in proliferating tumor cells with influx of CD4 and CD8 T-cells. Seven of the INT230-6 monotherapy patients had non injected tumor shrinkage in 9 visceral/deep lesions. Estimated median overall survival (mOS) was over 1 year for both arms.Biopsies confirm the dual anti-cancer mechanism, and study  subjects live longer than would be expected for these refractory populations.RECIST metrics (sum of longest diameters) such as progression free survival PFS or disease control rate (DCR) to gauge a drug’s efficacy are validated for use for systemically delivered therapies.The DCR rate >50 days for monotherapy was 47%; however, the INT230-6+PEM DCR was 33.3%. RECIST response principles are not ideal for use with this intratumoral administered therapy.Evaluation of tumors response is complicated by the large amount of INT230-6 repeatedly injected and retained in the tumors prior to the first efficacy scan. In addition, immune infiltration, could increase tumor size.Results in a neoadjuvant setting that a single injection causes almost complete necrosis of the entire tumor also indicates that longest diameter is inaccurate in capturing efficacy with this IT technology.A scan of a monotherapy chordoma tumor highlights this issue. Longest diameter declines 15%, whereas 2nd longest diameter declines 42%.In study, 75% of subjects had 1 or more risk factors (predicting a mOS of 90-160 daysv ). An exploratory analysis of cumulative dose relative to a subject’s incoming reported total tumor burden (TTB) was performed.Study reports mOS all monotherapy subjects and those receiving at > or < 40% of their TTB. For the PEM combination with a median follow-up of 143 days the mOS for subjects meeting all inclusion criteria (n=24) has not been met.Biopsies from injected tumors for patients are taken pretreatment cycle 1 day 0 (C1D0) and Day 28 (C2D0) for immunohistochemistry (IHC) analysis.IHC analysis included evaluation of CD3+ T-cells, CD4+ T-cells, CD8+, DAPI (cancer). There was a notable reduction in cancer cells in the post dose biopsies and an increase in CD3+ CD4+ and CD8+ T-cells.The results shows a significant influx of T-cells from a refractory, monotherapy ovarian cancer subject who prior to enrollment progressed on multiple platinum agents and several cycles of PD-1 antibody therapy. Similar results are seen in PEM combo treatment.INT230-6 components are retained in the tumor and demonstrate direct tumor killing in injected lesions. IHC results in injected lesions indicate dosing INT230-6 activates a T-cell mediated immune response.An exploratory analysis suggests survival for monotherapy subjects receiving INT230-6 dose to =40% of their TTB compares favorably to the <40% group.https://intensitytherapeutics.com/wp-content/uploads/ASCO-2022-INT230-6-Pembro-poster-V1-05-11-2022-rev4.pdf https://meetings.asco.org/abstracts-presentations/207587 June 02, 2022 Intensity Therapeutics&rsquo; INT230-6 Demonstrates Increased Survival as Either Monotherapy or in Combination with Ipilimumab in Patients with Relapsed, Refractory, Metastatic Sarcomas Based on the results announced by Intensity Therapeutics, Inc., in the press release, GlobalData inferred that a total of 27 subjects were analyzed in the study.Subjects were treated with and progressed following a median of three prior therapies in the monotherapy group and five prior treatments receiving the combination. INT230-6 was administered intratumorally every two weeks for five doses either alone or with 3 mg/kg of ipilimumab dosed every three weeks for four doses.Preliminary efficacy measured DCR and mOS. The DCR rate >50 days for monotherapy in sarcoma (excluding chordoma) was 56% and the DCR for INT230-6+IPI was observed as 57%.The overall survival of the control, all INT230-6 subjects in sarcoma and those receiving a cumulative dose of greater than 40% of their total tumor burden (TTB).Subjects receiving combination with ipilimumab have not yet reached median survival with 297 days median follow-up.  The Hazard Ratio (HR) for monotherapy subjects to the control was 0.290 CI (0.173, 0.494), whereas the HR for monotherapy subjects receiving INT230-6 at a dose great than or equal to 40% of the TTB was 0.236 CI (0.130, 0.423). https://intensitytherapeutics.com/intensity-therapeutics-int230-6-demonstrates-increased-survival-as-either-monotherapy-or-in-combination-with-ipilimumab-in-patients-with-relapsed-refractory-metastatic-sarcomas/ December 10, 2021 Presented at the 44th Annual San Antonio Breast Cancer Symposium (SABCS 2021), December 07 - 10, 2021, San Antonio, Texas, USA Safety and Efficacy of Int230-6, a Potential First-in-class Intratumoral Therapy, in Monotherapy and in Combination with Pembrolizumab: Results from the It-01 Study [Keynote-a10] in Subjects with Locally Advanced, Unresectable and Metastatic Breast Cancer Session: P5 - Poster Session 5 Abstract No.: P5-16-13 Philippe Bedard et al. Based on the results presented, GlobalData inferred that a total of seven subjects were analyzed in the study.Disease control rate (DCR), defined as the percent of subjects with a complete response, partial response, or stable disease at the first radiologic assessment, was 57%.Median overall survival was 12 months. Pre- and post- biopsy at 28 days after two INT230-6 doses (n= 3 evaluable, monotherapy, and combination with pembrolizumab) showed a 55% decrease in Ki67 and 69% reduction in viable cancer cells. In addition, multiplex immunofluorescence (n= 3 evaluable, combination with pembrolizumab) showed an influx of activated CD4 and CD8 T cells and in some cases a reduction in FoxP3 T-reg cells.There are early signs of cancer cell death in injected tumors and immune activation in heavily pre-treated subjects. Hematoxylin and Eosin (H&E) assessments were conducted to determine the percentage of viable tumor cells and necrotic cells. There were substantial reductions of cancer cells in biopsies from INT230-6 monotherapy subjects after two injections of INT230-6, when compared to baseline.Subject% Change in H&E assessment of viable tumor cellsKi67 Values by Image Analysis Pre/Post Treatment% Change in Ki67 of tumor cells by Image Analysis% Change in Ki67 of tumor cells by Manual AnalysisInjected tumor volume in cm3 and dose (mL) (C1D0/C1D14)001-008-86%72% / 5%-93%-97%4.91 (1.62/1.62)001-00950%78% / 33%-58%-64%46.83 (15.45/15.45002-022-72%98% / 93%5%-5%412 (60/100)Average-69%83% / 44%-52%-55%Disease control rate (DCR), defined as the percent of breast cancer subjects with a complete response, partial response, or stable disease at the first radiologic assessment was 57%.All subjects treatments were discontinued secondary to clinician’s decision, and not for disease progression. One subject (002-009) continued receiving INT230-6 injections despite a new lesion. https://www.abstractsonline.com/pp8/#!/10462/presentation/1687 December 10, 2021 Intensity Therapeutics Reports Promising Early Efficacy Results Using INT230-6 as a Monotherapy or in Combination with Pembrolizumab in Metastatic Breast Cancer at the 2021 San Antonio Breast Cancer Symposium Based on the results announced by Intensity Therapeutics, Inc., in the press release, GlobalData inferred that the median overall survival (mOS) of 12 months (CI:7.2, NR), which compares favorably to results observed in phase 1 studies of subjects with highly refractory or triple negative breast cancer.Abscopal effects were observed in a non-injected visceral lesion in 1 of 4 INT230-6 monotherapy subjects. A number of subjects came off study after completion of INT230-6 dosing without disease progression. One subject continued receiving INT230-6 injections despite a new lesion.Tissue analysis of matched paired (pre- and 28 days post-dose) biopsies in injected tumors from subjects receiving their first INT230-6 treatment cycle (two doses, n=3) had an average reduction in viable cancer cells of sixty-nine percent (69%). Immunohistochemistry results showed influx of CD4 and CD8 T-cells into the tumor microenvironment. https://intensitytherapeutics.com/intensity-therapeutics-reports-promising-early-efficacy-results-using-int230-6-as-a-monotherapy-or-in-combination-with-pembrolizumab-in-metastatic-breast-cancer-at-the-2021-san-antonio-breast-cancer-s/ November 13, 2021 Intensity Therapeutics Reports Promising Overall Survival Results Using INT230-6 as a Monotherapy or in Combination with Pembrolizumab or Ipilimumab to Treat Solid Tumors, at The Society for Immunotherapy of Cancer&rsquo;s (SITC) 36th Annual Meeting Based on the results announced by Intensity Therapeutics, Inc., in the press release, GlobalData inferred that the median overall survival (mOS) of 373 days for all monotherapy (n=53) subjects compares favorably to results observed in studies with similar phase 1 solid tumor populations.An exploratory analysis of dose relative to total tumor burden (TTB) showed that subjects receiving a dose of INT230-6 to <40% of their reported total tumor burden had a mOS of 96 days, while in subjects receiving a dose of INT230-6 to =40% of total tumor burden, had a mOS of 570 days (HR=0.104, 95% CI (0.038, 0.29)). Subjects  receiving the pembrolizumab combination had a mOS of 376 days (n=16).Comparison of the survival data of INT230-6 monotherapy to the pembrolizumab combo was not made due to different cancer types in the two cohort populations. Six subjects in the monotherapy arm who received an INT230-6 dose of =40% of the total tumor burden demonstrated abscopal effects (i.e., shrinkage of multiple non-injected tumors), further emphasizing the importance of dosing sufficient amounts to cause substantial tumor necrosis.Kaplan Meier estimates that approximately 60% of those of sarcoma subjects receiving INT230-6 monotherapy a dose volume greater than 40% of their total tumor burden will be alive at 1 year. These results compare favorable to results of survival data in studies of mixed refractory sarcoma subjects with similar prognostic factors scores (ECOG, LDH, # of metastatic sites) where the median survival is estimated to be 3 to 8 months.Biopsies showed substantial tumor necrosis, reduction of viable cancer, a decreased cancer proliferation as measured by Ki67, and increased Tumor Infiltrating Lymphocytes (CD4 and CD8 T-cells). Monotherapy subjects had abscopal effects (i.e., shrinkage of multiple non-injected tumors) https://intensitytherapeutics.com/intensity-therapeutics-reports-promising-overall-survival-results-using-int230-6-as-a-monotherapy-or-in-combination-with-pembrolizumab-or-ipilimumab-to-treat-solid-tumors-at-the-society-for-immunothe/ November 10, 2021 Presented at the 36th Virtual Annual Meeting and Pre-Conference Programs of the Society for Immunotherapy of Cancer (SITC 2021), November 10 - 14, 2021, Washington, D.C, USA Intratumoral INT230-6 Shows a Favorable Safety Profile and Early Signs of Efficacy in Advanced Soft Tissue Sarcoma with Monotherapy and in Combination with Ipilimumab [Intensity It-01; Bms#ca184-592] Session: Clinical Trials In Progress Abstract No.: 536 Matthew Ingham et al. Based on the results presented, GlobalData inferred that a total of 22 subjects were analyzed in the study.The median overall survival (OS) estimate for the monotherapy population (n=14) has not been reached with a median follow-up of 425 days, which compares favorably to results reported in basket studies of patients with similar prognostic factors (ECOG, LDH, # of metastatic sites).Immunohistochemistry results indicate influx of CD4 and CD8 T-cells without meaningful changes in circulating inflammatory cytokines. Abscopal effects in the monotherapy arm were observed in multiple lesions in 4 subjects. overall survival data for the 8 IPI combination subjects was immature.INT230-6 monotherapy survival compares favorably to published basket studies in soft tissue sarcoma subjects with similar prognostic factors. IHC and abscopal effects indicate dosing may activate a T-cell mediated immune response. https://jitc.bmj.com/content/9/Suppl_2/A566 November 10, 2021 Presented at the 36th Virtual Annual Meeting and Pre-Conference Programs of the Society for Immunotherapy of Cancer (SITC 2021), November 10 - 14, 2021, Washington, D.C, USA Survival and Immune Response Data from Intratumoral Int230-6 Alone (It-01) and with Pembrolizumab [Keynote-a10] in Subjects with Locally Advanced, Unresectable and Metastatic Solid Tumors Session: Clinical Trials In Progress Abstract No.: 501 Lilian Siu et al. Based on the results presented, GlobalData inferred that a total of 72 subjects were analyzed in the study.The median overall survival (mOS) estimated with removal of <2cm3 and >700cm3 tumor burdens was 433 days for monotherapy (n=51) and 513 days for pembrolizumab combination (n=12), which compares favorably to results observed in basket studies of subjects having similar prognostic factors (ECOG, LDH, # of metastatic sites).HC results indicate influx of CD4 and CD8 T-cells in injected lesions. No meaningful changes were observed in circulating inflammatory cytokines. Abscopal effects in the monotherapy arm were observed in 15 visceral/deep lesions in 11 subjects, primarily who received an INT230-6 dose >50% of their total tumor burden (TTB).Immunohistochemistry and abscopal results indicate dosing INT230-6 may also activate a T-cell mediated immune response. https://jitc.bmj.com/content/9/Suppl_2/A533  October 22, 2018Portage provides update on SalvaRx portfolio company, Intensity Therapeutics, Inc.Based on the results announced in the press release, GlobalData inferred some anti-tumor effects were observed with INT230-6 in injected tumors at low doses. Evidence of immune activation in the blood was also observed in the study.https://www.prnewswire.com/news-releases/portage-provides-update-on-salvarx-portfolio-company-intensity-therapeutics-inc-300734902.htmlNovember 2018                                                  Presented at the 33rd Annual Meeting of the Society for Immunotherapy of Cancer (SITC 2018), November 07-11, 2018, Washington, D.C, USAPhase 1/2 evaluation of intratumoral INT230-6 for the treatment of solid tumorsSession: Poster presentationAbstract No.: P622Anthony Olszanski et al.                               Based on the results presented, GlobalData inferred that subjects dosed every two weeks were maintained on treatment longer than the subjects treated once a month.Among 5/11(45%) evaluable subjects showed elevations in the circulating CD8+ T-cells, of these 60% of the subjects exhibited elevations in circulating CD4+ T-cells.https://jitc.biomedcentral.com/track/pdf/10.1186/s40425-018-0423-x (Pages 335-336)May 14, 2019Intensity Therapeutics to Present Data on Intratumoral Injection of INT230-6 at the Frontiers in Cancer Immunotherapy SymposiumBased on the results announced by Intensity Therapeutics, Inc., in the press release, GlobalData inferred that an increase in systemic CD4 and CD8 cells was observed in the study with evidence of tumor necrosis and abscopal effects..https://intensitytherapeutics.com/intensity-therapeutics-to-present-data-on-intratumoral-injection-of-int230-6-at-the-frontiers-in-cancer-immunotherapy-symposium/May 2019Presented at the 55th Annual Meeting of American Society of Clinical Oncology (ASCO 2019), May 31 - June 04, 2019, Chicago, Illinois, USASafety profile of INT230-6, a novel intratumoral (IT) formulation, during injections into a variety of refractory deep and superficial tumors with evidence of tumor regression and immune activationCategory: Developmental Immunotherapy and Tumor ImmunobiologyAbstract No.: 2602Anthony B El-Khoueiry et al.Based on the results presented, GlobalData inferred that superficial tumors demonstrated signs of response including flattening, areas of necrosis and ulceration.The tumor reduction was apparent in in both injected and bystander tumors, indicated an abscopal effect.An increase > 30% in CD8 T-cells was observed in the blood of 3/9 evaluable subjects.http://abstracts.asco.org/239/AbstView_239_259489.htmlJune 01, 2019Intensity Therapeutics Presents Positive Preliminary Phase 1/2 Results for Intratumoral Injection of INT230-6 at ASCO 2019Based on the results announced by Intensity Therapeutics, Inc., in the press release, GlobalData inferred thatBased on the results reported, INT230-6 showed anti-tumor effects at low doses.The immune activation observed was consistent with nonclinical data, as local delivery of INT230-6 into tumors had an immune response with increases of CD4+ and CD8+ T-cells in the blood and in the tumor microenvironment.Several subjects had shrinkage of non-injected tumors indicating an abscopal response.https://intensitytherapeutics.com/intensity-therapeutics-presents-positive-preliminary-phase-1-2-results-for-intratumoral-injection-of-int230-6-at-asco-2019/November 06, 2019Presented at the 34th Annual Meeting & Pre-Conference Programs of the Society for Immunotherapy of Cancer (SITC 2019), November 06 - 10, 2019, Maryland, USAIntratumoral INT230-6 injection into solid tumors kills tumors and induces immune cell infiltration leading to abscopal responses and prolonged disease control in multiple refractory cancer typesSession: Clinical Trial In ProgressAbstract No.: O31Jacob Thomas et al.Based on the results presented, GlobalData inferred that a total of 38 subjects were analysed.Circulating CD8+ T-cells increased above baseline in most subjects, with 40% of evaluable subjects having a marked >30% increase.Paired biopsies were available in five subjects and revealed >70% reduction in viable tumor cells in 3 out of 5 cases.Injected lesions demonstrated infiltration of CD4 and CD8 T-cells and reduction in FoxP3 Tregs. Several injected lesions showed asymptomatic tumor increases on the early scans (often with decreased contrast uptake), which decreased below baseline on subsequent scans while others showed tumor reduction already at the 2 month time point. The protocol suggested to continue treatment despite radiographic progression until clinical deterioration.Ten non injected tumors in seven subjects showed tumor shrinkage.https://jitc.biomedcentral.com/articles/10.1186/s40425-019-0764-0 May 20, 2020Intensity Therapeutics’ Abstract (#3016) Selected for Oral Presentation as Part of a Poster Discussion Session at ASCO 2020Based on the results announced by the Intensity Therapeutics, Inc. in the press release, GlobalData inferred that the  INT230-6 alone treated 13 subjects showed stable disease for greater than 6 months and 10 subjects had regression of uninjected tumors (abscopal effects).https://intensitytherapeutics.com/intensity-therapeutics-abstract-3016-selected-for-oral-presentation-as-part-of-a-poster-discussion-session-at-asco-2020/May 2020Presented at the 56th Annual Meeting of American Society of Clinical Oncology (ASCO 2020), May 29 - June 02, 2020, Chicago, Illinois, USAPharmacodynamic, safety, and efficacy results of a phase I/II trial of intratumoral INT230-6 alone (IT-01) or in combination with pembrolizumab (PEM) (Keynote A10) in patients with advanced solid tumorsAbstract No.: 3016Jacob Stephen Thomas etal.,Based on the results presented, GlobalData inferred that when compared to historical IV dosing, retention of drugs in the tumor was 95% and there was about > 30% decreases in diameter was seen in several injected and non-injected tumors and there was a substantial decrease in tumor volume ( > 50%). Circulating CD4 and CD8 T-cells was increased by 50% in stable subjects and there was a decreases in circulating T-cells (p < 0.05) in partial disease subjects.Dose-response has shown that monotherapy subjects who received  > 50% of tumors injected at dose/tumor volume ratio of > 1:4 (target dosing), has shown prolonged SD with 88%(7/8) having SD = 4mo and were correlated with decreased tumor viability on IHC, and increase in tumor-infiltrating lymphocytes (TIL’s). https://ascopubs.org/doi/abs/10.1200/JCO.2020.38.15_suppl.3016November 2020Presented at the 35th Virtual Annual Meeting & Pre-Conference Programs of the Society for Immunotherapy of Cancer (SITC 2020), November 09 - 14, 2020Novel intratumoral agent, INT230–6 induces cancer cell death, increases tumor infiltrates and results in durable benefit alone or in combination with pembrolizumab in refractory patientsSession: Regular and young investigator award abstractsAbstract no: 411Anthony El-Khoueiry et al.Based on the results presented, GlobalData inferred that 60 subjects were analyzed in the study.Rates were comparable for the single agent INT230-6 and the combination with pembrolizumab and in t")
# Out:
# Inserting batches in chromadb:   0%|          | 0/2 [00:00<?, ?it/s]WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: default-app-id--2eb9ba6476f5addd8c99eb4de5cc5f9c4d5d337cd654cc87d5643792f0f7fc41
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: default-app-id--30b44fd0eeb7872a1bac3b97357e851d9d227c6ce7aa60722234b87649a3cf3b
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: default-app-id--c55a8943e4994e5eee1ed01f8c3ff69b3f7141b7a5b272683cb7786932f48bb2
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: default-app-id--1310a6459d3d57210746f2491f38f7df26434fb081bc5e462284142f24d55643
# WARNING:chromadb.segment.impl.metadata.sqlite:Insert of existing embedding ID: default-app-id--10369f9f49b56dd573eb66333f333fbf97542a3b9a5747d34e73346c3e440b1b
# ...

# %%
answer = app.query("who is elon musk?")
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# <ipython-input-21-6a79cd4bbb02> in <cell line: 1>()
# ----> 1 answer = app.query("who is elon musk?")
#
# /usr/local/lib/python3.10/dist-packages/embedchain/embedchain.py in query(self, input_query, config, dry_run, where, citations, **kwargs)
#     509             )
#     510         else:
# --> 511             answer = self.llm.query(
#     512                 input_query=input_query, contexts=contexts_data_for_llm_query, config=config, dry_run=dry_run
#     513             )
#
# /usr/local/lib/python3.10/dist-packages/embedchain/llm/base.py in query(self, input_query, contexts, config, dry_run)
#     221                 return prompt
#     222
# --> 223             answer = self.get_answer_from_llm(prompt)
#     224             if isinstance(answer, str):
#     225                 logger.info(f"Answer: {answer}")
#
# ...

# %%
# !pip install pyngrok

# %%
# !mkdir -p /drive/ngrok-ssh
# %cd /drive/ngrok-ssh
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip -O ngrok-stable-linux-amd64.zip
# !unzip -u ngrok-stable-linux-amd64.zip
# !cp /drive/ngrok-ssh/ngrok /ngrok
# Out:
# --2024-05-23 23:18:13--  https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Resolving bin.equinox.io (bin.equinox.io)... 54.237.133.81, 18.205.222.128, 54.161.241.46, ...
# Connecting to bin.equinox.io (bin.equinox.io)|54.237.133.81|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13921656 (13M) [application/octet-stream]
# Saving to: ‘ngrok-stable-linux-amd64.zip’
#
# ngrok-stable-linux- 100%[===================>]  13.28M  46.7MB/s    in 0.3s
#
# 2024-05-23 23:18:13 (46.7 MB/s) - ‘ngrok-stable-linux-amd64.zip’ saved [13921656/13921656]
#
# Archive:  ngrok-stable-linux-amd64.zip
#   inflating: ngrok

# %%
# !ls -la
# !chmod +x ngrok
# Out:
# total 43500
# drwxr-xr-x 1 root root     4096 May 23 23:18 .
# drwxr-xr-x 1 root root     4096 May 23 23:15 ..
# drwxr-xr-x 4 root root     4096 May 22 13:22 .config
# -rwxr-xr-x 1 root root       25 May 23 23:16 myscript.sh
# -rwxr-xr-x 1 root root 30137501 Feb 10  2023 ngrok
# -rw-r--r-- 1 root root 13921656 May 23 23:18 ngrok-stable-linux-amd64.zip
# -rw------- 1 root root     3304 May 23 23:18 nohup.out
# -rw-r--r-- 1 root root   451749 May 23 23:18 ollama_model.log
# drwxr-xr-x 1 root root     4096 May 22 13:23 sample_data

# %%
# !pwd
# !ls -la
# Out:
# /content
# total 43500
# drwxr-xr-x 1 root root     4096 May 23 23:18 .
# drwxr-xr-x 1 root root     4096 May 23 23:15 ..
# drwxr-xr-x 4 root root     4096 May 22 13:22 .config
# -rwxr-xr-x 1 root root       25 May 23 23:16 myscript.sh
# -rwxr-xr-x 1 root root 30137501 Feb 10  2023 ngrok
# -rw-r--r-- 1 root root 13921656 May 23 23:18 ngrok-stable-linux-amd64.zip
# -rw------- 1 root root     3304 May 23 23:18 nohup.out
# -rw-r--r-- 1 root root   454597 May 23 23:18 ollama_model.log
# drwxr-xr-x 1 root root     4096 May 22 13:23 sample_data

# %%
import os
from google.colab import userdata
from pyngrok import ngrok, conf
import getpass

from pyngrok import ngrok, conf

print("Enter your authtoken, which can be copied from https://dashboard.ngrok.com/auth")
conf.get_default().auth_token = "2g6AcctgKhrdLZldEgoHtC9nZYw_4WkwCg6ggAWg2L9mjCJqL"


# Open a TCP ngrok tunnel to the SSH server
connection_string = ngrok.connect("22", "tcp").public_url

ssh_url, port = connection_string.strip("tcp://").split(":")
print(f" * ngrok tunnel available, access with `ssh root@{ssh_url} -p{port}`")
# Out:
# Enter your authtoken, which can be copied from https://dashboard.ngrok.com/auth
#  * ngrok tunnel available, access with `ssh root@4.tcp.ngrok.io -p16625`

# %%
# !sh ngrok config add-authtoken 2g6AcctgKhrdLZldEgoHtC9nZYw_4WkwCg6ggAWg2L9mjCJqL && ./ngrok http 11434
# Out:
# ngrok: 1: ELF: not found
# ngrok: 2: Syntax error: "|" unexpected

# %%
# !pip install ollama
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 2.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 8.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.7 MB/s eta 0:00:00
# ...

# %%
import ollama
def extractDrugs(prompt: str, model="mistral-openorca:latest"):
    SYS_PROMPT = (
        "Your task is to extract medical intervention names (drugs or therapies) from the details of a clinical trial. Each trial can have multiple interventions."
        "Give a json list of intevention names with the following information for each: name, type, is_new, conditions, list of trial ids, dosage & administration"
        "Separate the dosage & administration, keep intervention names concise, only including identifying information about the drug or therapy."
        "The response should have the following format:"
        '['
        '   {'
        '       "name": Intervention name,'
        '       "type": Biologic,'
        '       "is_new_drug": Yes (if its a new drug),'
        '       "conditions": ["condition1", "condition2"],'
        '       "dosage_administration": {'
        '           "dosage": "0.02%",'
        '           "administration": "topical, 4 times a day for 12 weeks"'
        '       }'
        "   },"
        "   {"
        '       "name": Intervention name 2,'
        '       "type": Small molecule'
        '       "is_new_drug": No (if its a generic, biosimilar or not mentioned),'
        '       "conditions": ["condition1", "condition2"],'
        '       "dosage_administration": {'
        '           "dosage": "0.02%",'
        '           "administration": "topical, 4 times a day for 12 weeks"'
        '       }'
        '   },'
        ']'
    )

    result = ollama.generate(
        model=model,
        prompt=prompt,
        system=SYS_PROMPT
    )
    print(result['response'])
    return result['response']

# %%
def trials2DrugsList(trials: list, model=None) -> list:
    # dataframe.reset_index(inplace=True)
    results = [ extractDrugs(trial, model) for trial in trials ]
    ## Flatten the list of lists to one single list of entities.
    return results

# %%
import xml.etree.ElementTree as ET

TAGS_TO_KEEP = [
    'Internal_Number',
    'TrialID',
    'Public_title',
    'Scientific_title',
    'Condition',
    'Intervention'
]

class TrialXMLLoader:
    def __init__(self, file_path):
        self.file_path = file_path

    def load(self):
        dict = self._structuredXMLLoader()
        trials = []
        for elem in dict.get('children', []):
            trials.append(','.join([
                f"""(tag: {x.get('tag','').strip()}, text: {x.get('text','').strip()})"""
                for x in elem.get('children', [])
                if x.get('text','') and x.get('tag','') in TAGS_TO_KEEP
            ]))
        return trials

    def _structuredXMLLoader(self):
        tree = ET.parse(self.file_path)
        root = tree.getroot()
        return self._parse_element(root)

    def _parse_element(self, element):
        return {
            "tag": element.tag,
            "text": element.text.strip() if element.text else None,
            "attributes": element.attrib,
            "children": [self._parse_element(child) for child in element]
        }

# %%
xml_path = f"./xml-1.xml"
loader = TrialXMLLoader(file_path=xml_path)

documents = loader.load()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-18-b8761dc2e51e> in <cell line: 4>()
#       2 loader = TrialXMLLoader(file_path=xml_path)
#       3
# ----> 4 documents = loader.load()
#
# <ipython-input-17-4f93d3dbe14c> in load(self)
#      15
#      16     def load(self):
# ---> 17         dict = self._structuredXMLLoader()
#      18         trials = []
#      19         for elem in dict.get('children', []):
#
# <ipython-input-17-4f93d3dbe14c> in _structuredXMLLoader(self)
#      26
#      27     def _structuredXMLLoader(self):
# ---> 28         tree = ET.parse(self.file_path)
#      29         root = tree.getroot()
#      30         return self._parse_element(root)
#
# /usr/lib/python3.10/xml/etree/ElementTree.py in parse(source, parser)
#    1220     """
#    1221     tree = ElementTree()
# -> 1222     tree.parse(source, parser)
#    1223     return tree
# ...

# %%
drugs_list = trials2DrugsList(documents[:10], model='phi3:medium')

# %%
import json
# json.loads(drugs_list[5])
drugs_list[3]

# %%
# !pip install -q pandasai

# %%
from pandasai.llm.local_llm import LocalLLM
import pandas as pd
from pandasai import SmartDataframe

# %%
model = LocalLLM(
    api_base="http://localhost:11434/v1",
    model="phi3:medium"
)

# %%
 df = SmartDataframe("/content/Master.csv", config={"llm": model})

# %%
df.chat("Cuantas filas y columnas tienen el dataframe")

# %%
df.chat("Stock de la referencia FOR464189")

# %%
df.chat("Cuál es el Stock de la referencia: FOR464189")
